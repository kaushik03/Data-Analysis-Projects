# %% [markdown]
# ### Importing Appropriate Libraries

# %%
# %pylab inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ### Importing Datasets

# %%
deliveries = pd.read_csv("/Coursera_Work/Data Analysis Projects/IPL/Data/deliveries.csv")

most_runs = pd.read_csv("/Coursera_Work/Data Analysis Projects/IPL/Data/most_runs_average_strikerate.csv")
players = pd.read_excel("/Coursera_Work/Data Analysis Projects/IPL/Data/Players.xlsx")
teams = pd.read_csv("/Coursera_Work/Data Analysis Projects/IPL/Data/teams.csv")
team_homeand_away = pd.read_csv("/Coursera_Work/Data Analysis Projects/IPL/Data/teamwise_home_and_away.csv")

# %% [markdown]
# ### Check Datasets for all the imported data.

# %%
deliveries.head()
# Out:
#    match_id  inning         batting_team                 bowling_team  over  \
# 0         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 1         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 2         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 3         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 4         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
#
#    ball    batsman non_striker    bowler  is_super_over  ...  bye_runs  \
# 0     1  DA Warner    S Dhawan  TS Mills              0  ...         0
# 1     2  DA Warner    S Dhawan  TS Mills              0  ...         0
# 2     3  DA Warner    S Dhawan  TS Mills              0  ...         0
# 3     4  DA Warner    S Dhawan  TS Mills              0  ...         0
# 4     5  DA Warner    S Dhawan  TS Mills              0  ...         0
#
#    legbye_runs  noball_runs  penalty_runs  batsman_runs  extra_runs  \
# ...

# %%
deliveries.dtypes
# Out:
# match_id             int64
# inning               int64
# batting_team        object
# bowling_team        object
# over                 int64
# ball                 int64
# batsman             object
# non_striker         object
# bowler              object
# is_super_over        int64
# wide_runs            int64
# bye_runs             int64
# legbye_runs          int64
# noball_runs          int64
# penalty_runs         int64
# batsman_runs         int64
# extra_runs           int64
# total_runs           int64
# player_dismissed    object
# dismissal_kind      object
# fielder             object
# dtype: object

# %%
deliveries.shape
# Out:
# (179078, 21)

# %%
deliveries.batting_team.unique()
# Out:
# array(['Sunrisers Hyderabad', 'Royal Challengers Bangalore',
#        'Mumbai Indians', 'Rising Pune Supergiant', 'Gujarat Lions',
#        'Kolkata Knight Riders', 'Kings XI Punjab', 'Delhi Daredevils',
#        'Chennai Super Kings', 'Rajasthan Royals', 'Deccan Chargers',
#        'Kochi Tuskers Kerala', 'Pune Warriors', 'Rising Pune Supergiants',
#        'Delhi Capitals'], dtype=object)

# %%
el_classico_inn1 = deliveries[(deliveries["batting_team"]== "Mumbai Indians") & (deliveries["bowling_team"]== "Chennai Super Kings")]

# %%
el_classico_inn1.shape
# Out:
# (3392, 21)

# %%
el_classico_inn1
# Out:
#         match_id  inning    batting_team         bowling_team  over  ball  \
# 15613         67       2  Mumbai Indians  Chennai Super Kings     1     1
# 15614         67       2  Mumbai Indians  Chennai Super Kings     1     2
# 15615         67       2  Mumbai Indians  Chennai Super Kings     1     3
# 15616         67       2  Mumbai Indians  Chennai Super Kings     1     4
# 15617         67       2  Mumbai Indians  Chennai Super Kings     1     5
# ...          ...     ...             ...                  ...   ...   ...
# 178949     11415       1  Mumbai Indians  Chennai Super Kings    20     2
# 178950     11415       1  Mumbai Indians  Chennai Super Kings    20     3
# 178951     11415       1  Mumbai Indians  Chennai Super Kings    20     4
# 178952     11415       1  Mumbai Indians  Chennai Super Kings    20     5
# 178953     11415       1  Mumbai Indians  Chennai Super Kings    20     6
#
#               batsman     non_striker    bowler  is_super_over  ...  bye_runs  \
# ...

# %%
ax = sns.barplot(x="over", y="total_runs", data= el_classico_inn1)

# %%
el_classico_inn2 = deliveries[(deliveries["batting_team"]== "Chennai Super Kings") & (deliveries["bowling_team"]== "Mumbai Indians")]
el_classico_inn2
# Out:
#         match_id  inning         batting_team    bowling_team  over  ball  \
# 15486         67       1  Chennai Super Kings  Mumbai Indians     1     1
# 15487         67       1  Chennai Super Kings  Mumbai Indians     1     2
# 15488         67       1  Chennai Super Kings  Mumbai Indians     1     3
# 15489         67       1  Chennai Super Kings  Mumbai Indians     1     4
# 15490         67       1  Chennai Super Kings  Mumbai Indians     1     5
# ...          ...     ...                  ...             ...   ...   ...
# 179073     11415       2  Chennai Super Kings  Mumbai Indians    20     2
# 179074     11415       2  Chennai Super Kings  Mumbai Indians    20     3
# 179075     11415       2  Chennai Super Kings  Mumbai Indians    20     4
# 179076     11415       2  Chennai Super Kings  Mumbai Indians    20     5
# 179077     11415       2  Chennai Super Kings  Mumbai Indians    20     6
#
#           batsman non_striker      bowler  is_super_over  ...  bye_runs  \
# ...

# %%
ax = sns.barplot(x="over", y="total_runs", data= el_classico_inn2)

# %%
mi_vs_csk = pd.concat([el_classico_inn1, el_classico_inn2])
mi_vs_csk.head()
# Out:
#        match_id  inning    batting_team         bowling_team  over  ball  \
# 15613        67       2  Mumbai Indians  Chennai Super Kings     1     1
# 15614        67       2  Mumbai Indians  Chennai Super Kings     1     2
# 15615        67       2  Mumbai Indians  Chennai Super Kings     1     3
# 15616        67       2  Mumbai Indians  Chennai Super Kings     1     4
# 15617        67       2  Mumbai Indians  Chennai Super Kings     1     5
#
#              batsman    non_striker    bowler  is_super_over  ...  bye_runs  \
# 15613       L Ronchi  ST Jayasuriya  JDP Oram              0  ...         0
# 15614       L Ronchi  ST Jayasuriya  JDP Oram              0  ...         0
# 15615       L Ronchi  ST Jayasuriya  JDP Oram              0  ...         0
# 15616  ST Jayasuriya       L Ronchi  JDP Oram              0  ...         0
# 15617  ST Jayasuriya       L Ronchi  JDP Oram              0  ...         0
#
# ...

# %%
mi_vs_csk.drop("match_id", axis = 1, inplace = True)

# %%
mi_vs_csk.describe()
# Out:
#             inning         over         ball  is_super_over    wide_runs  \
# count  6812.000000  6812.000000  6812.000000         6812.0  6812.000000
# mean      1.489724    10.283324     3.636671            0.0     0.041985
# std       0.499931     5.691104     1.822137            0.0     0.267671
# min       1.000000     1.000000     1.000000            0.0     0.000000
# 25%       1.000000     5.000000     2.000000            0.0     0.000000
# 50%       1.000000    10.000000     4.000000            0.0     0.000000
# 75%       2.000000    15.000000     5.000000            0.0     0.000000
# max       2.000000    20.000000     9.000000            0.0     5.000000
#
#           bye_runs  legbye_runs  noball_runs  penalty_runs  batsman_runs  \
# count  6812.000000  6812.000000  6812.000000        6812.0   6812.000000
# mean      0.003376     0.020552     0.004404           0.0      1.235026
# std       0.094576     0.195051     0.066221           0.0      1.632276
# ...

# %% [markdown]
# ## hence match summary for all matches between MI vs CSK is obtained

# %% [markdown]
# ## The data doesn't contain win and lose statistics also the year of win, hence it's hard to collect those information from this dataset
