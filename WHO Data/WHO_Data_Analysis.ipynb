# %%
# %pylab inline
import pandas as pd
import seaborn
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
data = pd.read_csv('MortIcd7.csv', dtype={"list" : "string", "Cause": "string" }) #WHO mortality data Dec-2019
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3071: DtypeWarning: Columns (2) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
data.head()
# Out:
#    Country  Admin1 SubDiv  Year List Cause  Sex  Frmat  IM_Frmat  Deaths1  \
# 0     1125     NaN    NaN  1955  07A  A000    1      1         8   107822
# 1     1125     NaN    NaN  1955  07A  A000    2      1         8   105750
# 2     1125     NaN    NaN  1955  07A  A001    1      1         8     1302
# 3     1125     NaN    NaN  1955  07A  A001    2      1         8      739
# 4     1125     NaN    NaN  1955  07A  A002    1      1         8       69
#
#    ...  Deaths21  Deaths22  Deaths23  Deaths24  Deaths25  Deaths26  \
# 0  ...    2013.0    2727.0    4126.0       NaN       NaN       214
# 1  ...    1745.0    3465.0    5963.0       NaN       NaN        82
# 2  ...       8.0       6.0       2.0       NaN       NaN         1
# 3  ...       2.0       1.0       2.0       NaN       NaN         0
# 4  ...       0.0       0.0       0.0       NaN       NaN         0
#
#    IM_Deaths1  IM_Deaths2  IM_Deaths3  IM_Deaths4
# 0       40543         NaN         NaN         NaN
# ...

# %% [markdown]
# ## Cleansing Data.

# %% [markdown]
# ### Description for Data
#
# #### Deaths      Age Groups
# --------------------------------------
#    1. Deaths1	    Deaths at all ages
#    2. Deaths2	    Deaths at age 0 year
#    3. Deaths3	    Deaths at age 1 year
#    4. Deaths4	    Deaths at age 2 years
#    5. Deaths5	    Deaths at age 3 years
#    6. Deaths6	    Deaths at age 4 years
#    7. Deaths7	    Deaths at age 5-9 years
#    8. Deaths8	    Deaths at age 10-14 years
#    9. Deaths9	    Deaths at age 15-19 years
#
#   10. Deaths10	Deaths at age 20-24 years
#   11. Deaths11	Deaths at age 25-29 years
#   12.  Deaths12	Deaths at age 30-34 years
#   13.  Deaths13	Deaths at age 35-39 years
#   14.  Deaths14	Deaths at age 40-44 years
#   15.  Deaths15	Deaths at age 45-49 years
#   16.  Deaths16	Deaths at age 50-54 years
#   17.  Deaths17	Deaths at age 55-59 years
#   18.  Deaths18	Deaths at age 60-64 years
#   19.  Deaths19	Deaths at age 65-69 years
#   20.  Deaths20	Deaths at age 70-74 years
#   21.  Deaths21	Deaths at age 75-79 years
#   21.  Deaths22	Deaths at age 80-84 years
#   23.  Deaths23	Deaths at age 85-89 years
#   24.  Deaths24	Deaths at age 90-94 years
#   25.  Deaths25	Deaths at age 95 years and above
#   26.  Deaths26	Deaths at age unspecified
#   27.  IM_deaths1	Infant deaths at age 0 day
#   28.  IM_deaths2	Infant deaths at age 1-6 days
#   29.  IM_deaths3	Infant deaths at age 7-27 days
#   30.  IM_deaths4	Infant deaths at age 28-364 days

# %%
#changing value of Gender/Sex for better interpretation and Understanding

# %%
gender = data["Sex"]

# %%
gender.replace(to_replace=[1,2], value= ["Male","Female"], inplace=True)

# %%
data["Kids"] = (data[data])
# Out:
#    Country  Admin1 SubDiv  Year List Cause     Sex  Frmat  IM_Frmat  Deaths1  \
# 0     1125     NaN    NaN  1955  07A  A000    Male      1         8   107822
# 1     1125     NaN    NaN  1955  07A  A000  Female      1         8   105750
# 2     1125     NaN    NaN  1955  07A  A001    Male      1         8     1302
# 3     1125     NaN    NaN  1955  07A  A001  Female      1         8      739
# 4     1125     NaN    NaN  1955  07A  A002    Male      1         8       69
#
#    ...  Deaths21  Deaths22  Deaths23  Deaths24  Deaths25  Deaths26  \
# 0  ...    2013.0    2727.0    4126.0       NaN       NaN       214
# 1  ...    1745.0    3465.0    5963.0       NaN       NaN        82
# 2  ...       8.0       6.0       2.0       NaN       NaN         1
# 3  ...       2.0       1.0       2.0       NaN       NaN         0
# 4  ...       0.0       0.0       0.0       NaN       NaN         0
#
#    IM_Deaths1  IM_Deaths2  IM_Deaths3  IM_Deaths4
# ...

# %%
data.count()
# Out:
# Country       281749
# Admin1          7916
# SubDiv          1792
# Year          281749
# List          281749
# Cause         281749
# Sex           281749
# Frmat         281749
# IM_Frmat      281749
# Deaths1       281749
# Deaths2       281749
# Deaths3       281749
# Deaths4       211278
# Deaths5       211278
# Deaths6       211278
# Deaths7       281749
# Deaths8       272693
# Deaths9       281749
# Deaths10      272693
# Deaths11      281749
# Deaths12      272693
# Deaths13      281749
# Deaths14      272693
# Deaths15      281749
# Deaths16      272693
# Deaths17      281749
# Deaths18      272693
# Deaths19      281749
# Deaths20      272693
# Deaths21      276861
# Deaths22      266869
# Deaths23      266869
# Deaths24           0
# Deaths25           0
# Deaths26      281749
# IM_Deaths1    281749
# IM_Deaths2      3220
# IM_Deaths3      3220
# IM_Deaths4      3220
# dtype: int64

# %%
data.set_index(["Year","Sex"]).count(level="Year")
# Out:
#       Country  Admin1  SubDiv   List  Cause  Frmat  IM_Frmat  Deaths1  \
# Year
# 1950     4356     268       0   4356   4356   4356      4356     4356
# 1951     6400     268       0   6400   6400   6400      6400     6400
# 1952     7276     268       0   7276   7276   7276      7276     7276
# 1953     7860     268       0   7860   7860   7860      7860     7860
# 1954     8452     268       0   8452   8452   8452      8452     8452
# 1955    14062     358       0  14062  14062  14062     14062    14062
# 1956    14322     351       0  14322  14322  14322     14322    14322
# 1957    14621     351       0  14621  14621  14621     14621    14621
# 1958    14963     358       0  14963  14963  14963     14963    14963
# 1959    15630     358       0  15630  15630  15630     15630    15630
# 1960    16336     358       0  16336  16336  16336     16336    16336
# 1961    18736     358     300  18736  18736  18736     18736    18736
# ...

# %%
#Data from Year 1950-1972

# %%
#Quick visualise of the data.

# %%
data.plot(figsize=(10,10))

# %%
#Analysing Death rate among the youths i.e. Age 15-19 in year 1950

# %%
yr1 = data[["Year", "Deaths9", "Deaths10", "Deaths11"]]

# %%
yr1.head()
# Out:
#    Year  Deaths9  Deaths10  Deaths11
# 0  1955     1059    1133.0      1639
# 1  1955      889     826.0      1414
# 2  1955       85     149.0       185
# 3  1955       75      84.0       129
# 4  1955        2       2.0         3

# %%
yr1.plot(subplots = True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x0000020B28E03970>,
# ...
#       dtype=object)

# %%
#Analysing Youths Died.

# %%
data["Youth_deaths"] = data["Deaths9"] + data["Deaths10"] + data["Deaths11"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('Deaths9', 'Deaths10', 'Deaths11')
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-24-fd177be7aef6> in <module>
# ...

# %%
data.head()
# Out:
#    Country  Admin1 SubDiv  Year List Cause     Sex  Frmat  IM_Frmat  Deaths1  \
# 0     1125     NaN    NaN  1955  07A  A000    Male      1         8   107822
# 1     1125     NaN    NaN  1955  07A  A000  Female      1         8   105750
# 2     1125     NaN    NaN  1955  07A  A001    Male      1         8     1302
# 3     1125     NaN    NaN  1955  07A  A001  Female      1         8      739
# 4     1125     NaN    NaN  1955  07A  A002    Male      1         8       69
#
#    ...  Deaths22  Deaths23  Deaths24  Deaths25  Deaths26  IM_Deaths1  \
# 0  ...    2727.0    4126.0       NaN       NaN       214       40543
# 1  ...    3465.0    5963.0       NaN       NaN        82       39632
# 2  ...       6.0       2.0       NaN       NaN         1           6
# 3  ...       1.0       2.0       NaN       NaN         0           4
# 4  ...       0.0       0.0       NaN       NaN         0           7
#
#    IM_Deaths2  IM_Deaths3  IM_Deaths4  Youth_deaths
# ...

# %%
data.plot.hist(x="Youth_deaths", y="Year")

# %%
data.drop(columns = 'Deaths24')
data.drop(columns = 'Deaths25')
#since both columns had 0 enteries
# Out:
#         Country  Admin1 SubDiv  Year List Cause     Sex  Frmat  IM_Frmat  \
# 0          1125     NaN    NaN  1955  07A  A000    Male      1         8
# 1          1125     NaN    NaN  1955  07A  A000  Female      1         8
# 2          1125     NaN    NaN  1955  07A  A001    Male      1         8
# 3          1125     NaN    NaN  1955  07A  A001  Female      1         8
# 4          1125     NaN    NaN  1955  07A  A002    Male      1         8
# ...         ...     ...    ...   ...  ...   ...     ...    ...       ...
# 281744     4340     NaN    NaN  1960  07B   202  Female      2         8
# 281745     4340     NaN    NaN  1960  07B   203    Male      2         8
# 281746     4340     NaN    NaN  1960  07B   203  Female      2         8
# 281747     4340     NaN    NaN  1960  07B   205    Male      2         8
# 281748     4340     NaN    NaN  1960  07B   205  Female      2         8
#
#         Deaths1  ...  Deaths21  Deaths22  Deaths23  Deaths24  Deaths26  \
# ...
